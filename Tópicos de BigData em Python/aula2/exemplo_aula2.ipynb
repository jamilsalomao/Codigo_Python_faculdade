# %%
import pandas as pd

# %%
colunas: list[str] = ["erros", "mapas", "data", "mapas_avaria"]

df: pd.DataFrame = pd.read_csv("data.csv", 
    names=colunas,
    skiprows=1,
).dropna()

df.head()
# Out:
#     erros  mapas                 data mapas_avaria
# 22    9.0   52.0  2024-04-02 00:00:00       17,31%
# 23   20.0   48.0  2024-04-03 00:00:00       41,67%
# 24   18.0   55.0  2024-04-04 00:00:00       32,73%
# 25   31.0   53.0  2024-04-05 00:00:00       58,49%
# 26   34.0   46.0  2024-04-06 00:00:00       73,91%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 22 to 152
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   erros         104 non-null    float64
#  1   mapas         104 non-null    float64
#  2   data          104 non-null    object
#  3   mapas_avaria  104 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.1+ KB

# %%
df['mapas_avaria'] = df['mapas_avaria'].\
                    str.replace(',', '.').\
                    str.replace('%', '').\
                    astype(float)

# %%
df.head()
# Out:
#     erros  mapas                 data  mapas_avaria
# 22    9.0   52.0  2024-04-02 00:00:00         17.31
# 23   20.0   48.0  2024-04-03 00:00:00         41.67
# 24   18.0   55.0  2024-04-04 00:00:00         32.73
# 25   31.0   53.0  2024-04-05 00:00:00         58.49
# 26   34.0   46.0  2024-04-06 00:00:00         73.91

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.head()
# Out:
#     erros  mapas       data  mapas_avaria
# 22    9.0   52.0 2024-04-02         17.31
# 23   20.0   48.0 2024-04-03         41.67
# 24   18.0   55.0 2024-04-04         32.73
# 25   31.0   53.0 2024-04-05         58.49
# 26   34.0   46.0 2024-04-06         73.91

# %%
df['semana'] = df['data'].dt.isocalendar().week

# %%
df.head()
# Out:
#     erros  mapas       data  mapas_avaria  semana
# 22    9.0   52.0 2024-04-02         17.31      14
# 23   20.0   48.0 2024-04-03         41.67      14
# 24   18.0   55.0 2024-04-04         32.73      14
# 25   31.0   53.0 2024-04-05         58.49      14
# 26   34.0   46.0 2024-04-06         73.91      14

# %%
df: pd.DataFrame = df.groupby(['semana'], as_index=False).agg(
    {'erros': 'sum', 'mapas': 'sum', 'mapas_avaria': 'mean'}
)

# %%
df.head()
# Out:
#    semana  erros  mapas  mapas_avaria
# 0      14  112.0  254.0        44.822
# 1      15  145.0  263.0        54.536
# 2      16   65.0  155.0        42.880
# 3      18   38.0   54.0        70.370
# 4      19  176.0  280.0        62.168

# %%
df['erros_percentual'] = round((df['erros'] / df['mapas']) * 100, 2)

probabilidade: float = df['erros'].sum() / df['mapas'].sum()

# %%
def limites_controle(observacoes: int, conformidade: int, p: float = 0.0, tipo: int = 1) -> tuple[float, float, float]:
    if p == 0.0:
        p = (observacoes - conformidade) / observacoes if tipo == 1 else conformidade / observacoes
        
    desvio: float = (p * (1 - p) * (1 / observacoes)) ** (1 / 2)
    lic: float = p - 3 * desvio
    lsc: float = p + 3 * desvio
    
    return lic, p, lsc

# %%
df[['lic', 'p', 'lsc']] = df.apply(
    lambda x:
    limites_controle(
        x['mapas'],
        x['erros'],
        p=probabilidade,
        tipo=1
    ), axis=1, result_type='expand'
)

# %%
df
# Out:
#     semana  erros  mapas  mapas_avaria  erros_percentual       lic         p  \
# 0       14  112.0  254.0     44.822000             44.09  0.383025  0.477044
# 1       15  145.0  263.0     54.536000             55.13  0.384648  0.477044
# 2       16   65.0  155.0     42.880000             41.94  0.356689  0.477044
# 3       18   38.0   54.0     70.370000             70.37  0.273136  0.477044
# 4       19  176.0  280.0     62.168000             62.86  0.387497  0.477044
# 5       20  115.0  226.0     50.852500             50.88  0.377371  0.477044
# 6       21   85.0  262.0     34.090000             32.44  0.384472  0.477044
# 7       22  163.0  251.0     79.438000             64.94  0.382465  0.477044
# 8       23  181.0  263.0     68.620000             68.82  0.384648  0.477044
# 9       24  117.0  260.0     44.554000             45.00  0.384117  0.477044
# 10      25  174.0  249.0     69.190000             69.88  0.382086  0.477044
# 11      26  132.0  265.0     48.972000             49.81  0.384997  0.477044
# 12      27   90.0  251.0     36.102000             35.86  0.382465  0.477044
# 13      28  116.0  262.0     43.788000             44.27  0.384472  0.477044
# 14      29  103.0  294.0     34.306000             35.03  0.389655  0.477044
# 15      30  128.0  278.0    381.146667             46.04  0.387175  0.477044
# 16      31  128.0  293.0     44.428000             43.69  0.389506  0.477044
# 17      32  101.0  292.0     33.722000             34.59  0.389356  0.477044
# 18      33  120.0  289.0     41.836000             41.52  0.388902  0.477044
# 19      34  101.0  300.0     33.538000             33.67  0.390533  0.477044
# 20      35  203.0  289.0    473.548333             70.24  0.388902  0.477044
# 21      36   67.0  246.0     27.055000             27.24  0.381509  0.477044
#
#          lsc
# 0   0.571064
# 1   0.569441
# 2   0.597400
# 3   0.680953
# 4   0.566592
# 5   0.576718
# 6   0.569617
# 7   0.571624
# 8   0.569441
# 9   0.569972
# 10  0.572003
# 11  0.569092
# 12  0.571624
# 13  0.569617
# 14  0.564434
# 15  0.566914
# 16  0.564583
# 17  0.564733
# 18  0.565187
# 19  0.563556
# 20  0.565187
# 21  0.572580
